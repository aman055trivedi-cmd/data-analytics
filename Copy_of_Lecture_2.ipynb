# %% [markdown]
# <a href="https://colab.research.google.com/github/aman055trivedi-cmd/data-analytics/blob/main/Copy_of_Lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# WAP to print a number in Python

a=10
print(a)
# Out:
# 1

# %%
# WAP to add two nums..
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
#WAP to perform all arithmatic operations
a=10
b=20
print("Additon",a+b)
print("Subtration",a-b)
print("Multiply",a*b)
print("Divide",a/b)
print("Modulo..",a%b)
# Out:
# Additon 30
# Subtration -10
# Multiply 200
# Divide 0.5
# Modulo.. 10

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Flight Problem
Flights = int(input("ENter Total Flights: "))
Flight_Takeoff =int(input("Enter Flights Take Off: "))
Flight_Landed = int(input("Enter Landed Flight: "))
result = Flights-Flight_Takeoff+Flight_Landed
print(result)
# Out:
# ENter Total Flights: 200
# Enter Flights Take Off: 10
# Enter Landed Flight: 10
# 200

# %%
#WAP to convert Number of Days into Number of Seconds..
days =float(input("Enter No.. of Days: "))
sec = days*24*60*60
print(sec, "Seconds in ", days, "Day")
# Out:
# Enter No.. of Days: 2
# 172800.0 Seconds in  2.0 Day

# %%
#WAP to convert temprature in celsius into fahrenheit

celsius = float(input("Enter temp in Celsius: "))
f = c*(9/5)+32
print(celsius," in Fahrenheit is : ",f)
# Out:
# Enter temp in Celsius: 39
# 39.0  in Fahrenheit is :  86.0

# %%
"""
WAP for the following:
1)To find out area of Square, Rectange and Triangle
2)Perimeter of Sphere
3)WAP to Find the volume of cube
4)WAP to find a square of a number
5)WAP to calculate pythagoras theorem
"""

# %%
#QUE 1.
a= int(input("Enter the side of Sqaure: "))
sq_area= a**2
print("Area of Square is : ", sq_area)

rec_side1=int(input("Enter Side 1 of Rectangle: "))
rec_side2=int(input("Enter Side 1 of Rectangle: "))
rec_area =rec_side1*rec_side2
print("Area of Rectangle is: ", rec_area)

Base = int(input("Enter Base of triangle: "))
Height= int(input("Enter Height of triangle: "))
tri_area=(Base*Height)/2
print("Area of Triangle is : ", tri_area)
# Out:
# Enter the side of Sqaure: 5
# Area of Square is :  25
# Enter Side 1 of REctangle: 3
# Enter Side 1 of REctangle: 5
# Area of Rectangle is:  15
# Enter Base od triangle: 5
# Enter Height of triangle: 10
# Area of Triangle is :  25.0

# %%
#QUE 2 2*pi*r

radius =int(input("Enter the Radius of Sphere :"))
peri_sph = 2*3.14*radius
print("Perimeter of Sphere is ",peri_sph)
# Out:
# Enter the Radius of Sphere :5
# Perimeter of Sphere is  31.400000000000002

# %%
# 3)WAP to Find the volume of cube
a= int(input("Enter the side of Cube: "))
vol_cube = a**3
print("Volume of Cube is : ", vol_cube)
# Out:
# Enter the side of Cube: 20
# Volume of Cube is :  8000

# %%
# 4)WAP to find a square of a number
num = int(input("Enter Number: "))
sq_num = num**2
print(sq_area)
# Out:
# Enter Number: 5
# 25

# %%
# 5)WAP to calculate pythagoras theorem

import math
Base =int(input("Enter Side 1: "))
Par =int(input("Enter Side 2: "))
h= math.sqrt(Base**2 + b**2)
print(h)
# Out:
# Enter Side 1: 5
# Enter Side 2: 4
# 20.615528128088304

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
